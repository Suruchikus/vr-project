# %%
import pygame
from pygame.locals import *
from OpenGL.GL import *
from OpenGL.GLU import *
import pywavefront
import cv2
import mediapipe as mp

SCREEN_WIDTH, SCREEN_HEIGHT = 1200, 700



class HandTracking:
    mp_drawing = mp.solutions.drawing_utils
    mp_drawing_styles = mp.solutions.drawing_styles
    def __init__(self):
        mp_hands = mp.solutions.hands
        self.hand_tracking = mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5)
        self.hand_x = 0
        self.hand_y = 0
        self.results = None
        self.hand_closed = False

    def scan_hands(self, image):
        rows, cols, _ = image.shape
        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        self.results = self.hand_tracking.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        self.hand_closed = False

        if self.results.multi_hand_landmarks:
            
            for hand_landmarks in self.results.multi_hand_landmarks:
                x, y = hand_landmarks.landmark[9].x, hand_landmarks.landmark[9].y
                self.hand_x = int(x * SCREEN_WIDTH)
                self.hand_y = int(y * SCREEN_HEIGHT)

                x1, y1 = hand_landmarks.landmark[12].x, hand_landmarks.landmark[12].y

                if y1 > y:
                    mp_drawing = mp.solutions.drawing_utils
                    self.hand_closed = True
                    mp_hands = mp.solutions.hands
                   
                mp_hands = mp.solutions.hands
                mp_drawing = mp.solutions.drawing_utils
                mp_drawing_styles = mp.solutions.drawing_styles
                mp_drawing.draw_landmarks(
                    image,
                    hand_landmarks,
                    mp_hands.HAND_CONNECTIONS,
                    mp_drawing_styles.get_default_hand_landmarks_style(),
                    mp_drawing_styles.get_default_hand_connections_style())

        return image

    def is_hand_closed(self):
        return self.hand_closed

class OpenGLScene:
    def __init__(self):
        pygame.init()
        display = (800, 600)
        pygame.display.set_mode(display, DOUBLEBUF | OPENGL)
        gluPerspective(45, (display[0] / display[1]), 1, 500.0)
        glTranslatef(0.0, 0.0, -10)

        self.scene = pywavefront.Wavefront('Cube.obj', collect_faces=True)
        self.scene_box = self.calculate_scene_box()
        self.scene_trans = [-(self.scene_box[1][i] + self.scene_box[0][i]) / 2 for i in range(3)]
        self.scene_scale = self.calculate_scene_scale()

    def calculate_scene_box(self):
        scene_box = (self.scene.vertices[0], self.scene.vertices[0])
        for vertex in self.scene.vertices:
            min_v = [min(scene_box[0][i], vertex[i]) for i in range(3)]
            max_v = [max(scene_box[1][i], vertex[i]) for i in range(3)]
            scene_box = (min_v, max_v)
        return scene_box

    def calculate_scene_scale(self):
        scaled_size = 5
        scene_size = [self.scene_box[1][i] - self.scene_box[0][i] for i in range(3)]
        max_scene_size = max(scene_size)
        return [scaled_size / max_scene_size for i in range(3)]

    def draw_model(self):
        glPushMatrix()
        glScalef(*self.scene_scale)
        glTranslatef(*self.scene_trans)

        for mesh in self.scene.mesh_list:
            glBegin(GL_TRIANGLES)
            for face in mesh.faces:
                for vertex_i in face:
                    glVertex3f(*self.scene.vertices[vertex_i])
            glEnd()

        glPopMatrix()

    def main_loop(self):
        hand_position_prev_x = 0
        hand_position_prev_y = 0
        
        # phand_position_prev = (0, 0)
        while True:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    pygame.quit()
                    quit()

                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_LEFT:
                        glTranslatef(-0.5, 0, 0)
                    if event.key == pygame.K_RIGHT:
                        glTranslatef(0.5, 0, 0)
                    if event.key == pygame.K_UP:
                        glTranslatef(0, 1, 0)
                    if event.key == pygame.K_DOWN:
                        glTranslatef(0, -1, 0)

            glRotatef(1, 5, 1, 1)
            glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)

            glPolygonMode(GL_FRONT_AND_BACK, GL_LINE)
            self.draw_model()
            glPolygonMode(GL_FRONT_AND_BACK, GL_FILL)

            pygame.display.flip()
            pygame.time.wait(15)
            hand_tracker = HandTracking()
            cap = cv2.VideoCapture(0)  
            ret, frame = cap.read()
            processed_frame = hand_tracker.scan_hands(frame)
            hand_closed = hand_tracker.is_hand_closed()
            if hand_closed:
                hand_position_curr_x = hand_tracker.hand_x  # Current hand position
                hand_position_curr_y = hand_tracker.hand_y
                # Determine the direction of movement
                if hand_position_curr_x > hand_position_prev_x:
                    # Hand moved right
                    glTranslatef(0.1, 0, 0)  # Translate cube right
                elif hand_position_curr_x < hand_position_prev_x:
                   # Hand moved left
                   glTranslatef(-0.1, 0, 0)  # Translate cube left
                if hand_position_curr_y > hand_position_prev_y:
                    # Hand moved right
                        glTranslatef(0, 0.1, 0)  # Translate cube up
                elif hand_position_curr_y < hand_position_prev_y:
                   # Hand moved left
                   glTranslatef(0, -0.1, 0) # Translate cube left
                # Update previous hand position
                hand_position_prev_x = hand_position_curr_x
                hand_position_prev_y = hand_position_curr_y
                
SCREEN_WIDTH, SCREEN_HEIGHT = 1200, 1200

def main():
    scene = OpenGLScene()
    scene.main_loop()

if __name__ == "__main__":
    main()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713402848.381058 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# I0000 00:00:1713402849.703409 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402849.853790 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402849.995368 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.151116 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.274340 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.404870 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.540853 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.673049 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.803347 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402850.958763 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.088994 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.224764 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.359274 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.491009 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.625382 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.759289 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402851.892687 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.024840 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.157707 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.291505 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.423583 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.557705 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.691989 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.824533 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402852.958152 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.090285 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.222499 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.358106 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.491702 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.623598 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402853.759332 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402853.890390 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.024811 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.156835 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.291632 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.423827 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.558600 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.692045 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.824250 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402854.957588 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.091113 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.224384 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.357526 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.490167 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.622812 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402855.757132 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402855.891313 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.057982 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.189050 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.324187 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.457516 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.590381 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.724462 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402856.891461 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.058015 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.222151 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.354418 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.490898 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.623795 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.756161 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402857.890223 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.024077 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.189559 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402858.323683 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.455973 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.591013 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.754033 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402858.888903 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.023795 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.191023 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.356075 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.490438 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.654609 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.789458 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402859.954826 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402860.088762 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402860.223674 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402860.390405 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402860.555565 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402860.723300 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402860.888873 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.056021 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.219749 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.355969 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.520532 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.655504 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.820304 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402861.956040 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.145557 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.288672 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.453419 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.589153 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.752294 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402862.888551 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.053801 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.188308 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402863.353063 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.488294 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.658750 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.821103 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402863.990047 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.152744 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.288139 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.455617 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.622311 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.788836 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402864.955758 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.121219 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.288605 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.455697 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.621631 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.789096 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402865.953536 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402866.122456 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402866.288705 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402866.454777 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402866.621121 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402866.787483 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402866.952725 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.121815 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.288528 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.454667 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.620267 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.787445 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402867.954934 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402868.121672 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402868.287290 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402868.454461 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402868.620057 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402868.787059 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402868.954034 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.119548 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.286938 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.453875 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.620674 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.787046 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402869.953532 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.122059 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.287359 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.453745 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.621094 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.785985 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402870.954619 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402871.119868 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402871.286591 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402871.453687 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402871.619403 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402871.786337 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402871.953754 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.119313 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.287477 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.453008 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.620776 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.785949 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402872.953029 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.120251 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.289440 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.452558 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.598106 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.731183 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.863013 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402873.997858 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402874.188293 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402874.331312 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402874.462491 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402874.617739 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402874.786115 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402874.952811 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.119942 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.285548 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.451739 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.618847 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.786263 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402875.951188 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.118513 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.285794 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.451454 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.618674 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.785718 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402876.952552 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402877.115653 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402877.282785 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402877.450683 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402877.616615 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402877.783354 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402877.950080 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.116773 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.282858 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.449290 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.622934 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.781603 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402878.916959 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402879.082644 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402879.251437 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402879.415927 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402879.590716 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402879.748765 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402879.894703 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.056709 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.214682 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.390942 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.550163 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.718002 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402880.882517 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.051225 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.216112 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.383244 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.548939 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.717258 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402881.884947 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402882.028389 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402882.184576 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402882.349280 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402882.519161 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402882.689696 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402882.883967 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.050211 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.216540 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.390086 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.550497 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.718043 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402883.882832 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.028329 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.161962 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.316330 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.461852 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.621065 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.784437 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402884.951768 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402885.116115 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402885.282272 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402885.455994 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402885.615389 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402885.787430 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402885.949445 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.117938 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.281328 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.459410 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.615800 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.782055 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402886.982683 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402887.149052 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402887.319178 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402887.481321 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402887.646530 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402887.816043 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402887.983293 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.125863 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.287258 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.448653 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.615346 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.760915 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402888.915875 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.082645 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.247638 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.414293 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.613743 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.782442 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402889.948696 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.113828 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.259772 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.393030 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.523329 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# Context leak detected, msgtracer returned -1
# I0000 00:00:1713402890.681246 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.826276 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402890.980358 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.147294 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.313989 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.478318 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.647032 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.828412 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402891.959431 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402892.147383 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402892.315334 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1713402892.457645 11014050 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 166
#     163     scene.main_loop()
#     165 if __name__ == "__main__":
# --> 166     main()
#
# Cell In[1], line 163, in main()
#     161 def main():
#     162     scene = OpenGLScene()
# --> 163     scene.main_loop()
#
# Cell In[1], line 134, in OpenGLScene.main_loop(self)
#     132 pygame.display.flip()
#     133 pygame.time.wait(15)
# --> 134 hand_tracker = HandTracking()
#     135 cap = cv2.VideoCapture(0)
#     136 ret, frame = cap.read()
#
# Cell In[1], line 18, in HandTracking.__init__(self)
#      16 def __init__(self):
#      17     mp_hands = mp.solutions.hands
# ---> 18     self.hand_tracking = mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5)
#      19     self.hand_x = 0
#      20     self.hand_y = 0
#
# File /opt/anaconda3/lib/python3.11/site-packages/mediapipe/python/solutions/hands.py:114, in Hands.__init__(self, static_image_mode, max_num_hands, model_complexity, min_detection_confidence, min_tracking_confidence)
#      89 def __init__(self,
#      90              static_image_mode=False,
#      91              max_num_hands=2,
#      92              model_complexity=1,
#      93              min_detection_confidence=0.5,
#      94              min_tracking_confidence=0.5):
#      95   """Initializes a MediaPipe Hand object.
#      96
#      97   Args:
#    (...)
#     112       https://solutions.mediapipe.dev/hands#min_tracking_confidence.
#     113   """
# --> 114   super().__init__(
#     115       binary_graph_path=_BINARYPB_FILE_PATH,
#     116       side_inputs={
#     117           'model_complexity': model_complexity,
#     118           'num_hands': max_num_hands,
#     119           'use_prev_landmarks': not static_image_mode,
#     120       },
#     121       calculator_params={
#     122           'palmdetectioncpu__TensorsToDetectionsCalculator.min_score_thresh':
#     123               min_detection_confidence,
#     124           'handlandmarkcpu__ThresholdingCalculator.threshold':
#     125               min_tracking_confidence,
#     126       },
#     127       outputs=[
#     128           'multi_hand_landmarks', 'multi_hand_world_landmarks',
#     129           'multi_handedness'
#     130       ])
#
# File /opt/anaconda3/lib/python3.11/site-packages/mediapipe/python/solution_base.py:263, in SolutionBase.__init__(self, binary_graph_path, graph_config, calculator_params, graph_options, side_inputs, outputs, stream_type_hints)
#     257   self._graph.observe_output_stream(stream_name, callback, True)
#     259 self._input_side_packets = {
#     260     name: self._make_packet(self._side_input_type_info[name], data)
#     261     for name, data in (side_inputs or {}).items()
#     262 }
# --> 263 self._graph.start_run(self._input_side_packets)
#
# RuntimeError: Service "kGpuService", required by node palmdetectioncpu__ImageToTensorCalculator, was not provided and cannot be created: ; RET_CHECK failure (mediapipe/gpu/gl_context_nsgl.cc:122) (err)==(kCVReturnSuccess)Error at CVOpenGLTextureCacheCreate
